# %%
import os
print(os.getcwd())
# Out:
# /home/leandro/Documents/python/AdventureWorksProject/notebooks

# %%
import sys
import os

# Caminho da raiz do projeto
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

# Adiciona ao sys.path
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from scripts.conecta_sql import conectar_sql_server
from scripts.consultas import (
    vendas_por_territorio,
    produtos_mais_vendidos,
    vendas_por_ano,
    vendas_por_cliente
)
from scripts.visualizacoes import (
    grafico_vendas_por_territorio,
    grafico_produtos_mais_vendidos,
    grafico_vendas_por_ano,
    grafico_vendas_por_cliente
)

# %%
conn = conectar_sql_server()

# %%
df_territorio = vendas_por_territorio(conn)
grafico_vendas_por_territorio(df_territorio)
# Out:
# /home/leandro/Documents/python/AdventureWorksProject/scripts/consultas.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, conn)

# %%
df_produtos = produtos_mais_vendidos(conn, limite=10)
grafico_produtos_mais_vendidos(df_produtos)
# Out:
# /home/leandro/Documents/python/AdventureWorksProject/scripts/consultas.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, conn)

# %%
df_ano = vendas_por_ano(conn)
grafico_vendas_por_ano(df_ano)

# %%
df_clientes = vendas_por_cliente(conn, limite=8)
grafico_vendas_por_cliente(df_clientes)

# %%
conn.close()
